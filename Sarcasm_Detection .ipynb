# %%
import pandas as pd
import math
import re
import json
import nltk
from nltk.corpus import stopwords
dataset_file='Sarcasm_Headlines_Dataset.json'
stop_words = stopwords.words('english')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
def load_dataset(file):
    data = []
    with open(file) as f:
        for line in f.readlines():
            j = json.loads(line)
            url, headline, sarcastic = j['article_link'], j['headline'], j['is_sarcastic']
            data.append([url, headline, sarcastic])
    df=pd.DataFrame(data, columns=['article_link', 'headline', 'is_sarcastic'])
    return df

# %%
def Select_Features(data):
    features_to_keep=['headline','is_sarcastic']
    cols_to_drop=[]   
    for col in data.columns:
        if col not in features_to_keep:
            cols_to_drop.append(col)
            data=data.drop([col],axis=1)
    return data

# %%
def remove_symbols(comment):
    comment = re.sub("[']", '', comment)
    comment = re.sub("[^\w]", ' ', comment)
    return comment

# %%
def remove_stop_words(comment):
    splited_comment=comment.split()
    final_comment=""
    for word in splited_comment:
        if word not in stop_words:
            word=lemmitization(word)
            final_comment+=word
            final_comment+=" "
    return final_comment

# %%
def Pre_Processing(data):
    for i in range(0,len(data)):
        comment=remove_symbols(data.iloc[i,0])
        comment=remove_stop_words(comment)
        data.iloc[i,0]=comment.lower()
    return data

# %%
def lemmitization(word):
    return lemmatizer.lemmatize(word)

# %%
def Build_TF_Vector(d):
    tf_words={}
    checked_list=[]
    final_words=[]
    for i in d['headline'].index:
        line=d['headline'][i].split()
        for word in line:
            if word not in checked_list:
                tf_words[word]=1
                checked_list.append(word)
            else:
                tf_words[word]+=1
    return tf_words

# %%
def prior_probabilty(arr_data):
    probabities={}
    probabities[1]=arr_data['is_sarcastic'].value_counts()[1]
    probabities[0]=arr_data['is_sarcastic'].value_counts()[0]
    return probabities

# %%
def Remove_Low_Freq(tf_vector):
    final_tf={}
    for word in tf_vector:
        if(tf_vector[word]>=5):
            final_tf[word]=(tf_vector[word])
    return final_tf

# %%
def get_unique_words(train,vocab):
    words=[]
    for line in train['headline']:
        line=line.split()
        for word in line:
            if word in vocab and word not in words:
                words.append(word)
            
    return words

# %%
def Words_Frequencies_Class(train,words):
    
    list_w=[]
    total_words_class={}
    total_words_class[0]=0
    total_words_class[1]=0
    count_words={}
    for i in range(0,len(train)):
        row=train.iloc[i]
        lines=row[0].split()
        label=row[1]
        for word in lines:
            if label==1:
                total_words_class[1]+=1
            else:
                total_words_class[0]+=1
            if word in words and word not in list_w:
                list_w.append(word)
                count_words[word]={}
                count_words[word][0]=1
                count_words[word][1]=1
            elif label==1 and word in list_w:
                count_words[word][1]+=1
            elif label==0 and word in list_w:
                count_words[word][0]+=1
                
    return total_words_class,count_words

# %%
def Calculate_Probalities(total_count,word_count,total_unique):
    prob={}
    for word in word_count:
        prob[word]={}
        prob[word][0]=((word_count[word][0]+1)/(total_unique+total_count[0]))
        prob[word][1]=((word_count[word][1]+1)/(total_unique+total_count[1]))
    
        
    return prob

# %% [markdown]
# # MultiNomial Naive Bayes
#
# Formula = Term_Freq(feature(i)+1)/(Total_Unique_Words)+(Total_Words(each_class))

# %%
def NaiveBayes(train,vocab):
    words=get_unique_words(train,vocab)
    total_words=len(words)
    prior_prob=prior_probabilty(train)
    total_count,word_count=Words_Frequencies_Class(train,words)
    prob=Calculate_Probalities(total_count,word_count,total_words)
    
    prob['pr_0']=prior_prob[0]
    prob['pr_1']=prior_prob[1]
    prob['t_words']=total_words
    prob['class0']=total_count[0]
    prob['class1']=total_count[1]
    return prob

# %%
def test_dataset(trained,test):
    prior_prob=prior_probabilty(train)
    true_predicted=0
    output=[]
    tf=1
    c=0
    true_prob=1
    false_prob=1
    predicted=""
    for i in range(0,len(test)):
        predicted=""
        true_prob=1
        false_prob=1
        row=test.iloc[i]
        line=row[0].split()
        actual=row[1]
        for w in line:
            if w in trained:
                true_prob*=trained[w][1]
                false_prob*=trained[w][0]
            else:
                true_prob*=(1+tf)/((trained['t_words']+trained['class1']))
                false_prob*=(1+tf)/((trained['t_words']+trained['class0']))
        true_prob=(true_prob * trained['pr_1'])
        false_prob=(false_prob * trained['pr_0'])
        if true_prob>false_prob:
            predicted=1
        else:
            predicted=0
        output.append(predicted)
    return output

# %%
def Accuracy(actual,predicted):
    true_predicted=0
    for i in range(0,len(predicted)):
        if(actual[i]==predicted[i]):
            true_predicted+=1
    accuracy=(true_predicted/len(test))*100
    return accuracy

# %%
def check_sentence(trained,sent):
    line=sent.split()
    true_prob=1
    false_prob=1
    tf=1
    for w in line:
        if w in trained:
            true_prob*=trained[w][1]
            false_prob*=trained[w][0]
        else:
            true_prob*=(1+tf)/((trained['t_words']+trained['class1']))
            false_prob*=(1+tf)/((trained['t_words']+trained['class0']))
    true_prob=(true_prob * trained['pr_1'])
    false_prob=(false_prob * trained['pr_0'])
    if(true_prob>false_prob):
        return "Sarcastic"
    else:
        return "Not Sarcastic"

# %%
data=load_dataset(dataset_file) # Read Data file
data
# Out:
#                                             article_link  \
# 0      https://www.huffingtonpost.com/entry/versace-b...
# 1      https://www.huffingtonpost.com/entry/roseanne-...
# 2      https://local.theonion.com/mom-starting-to-fea...
# 3      https://politics.theonion.com/boehner-just-wan...
# 4      https://www.huffingtonpost.com/entry/jk-rowlin...
# 5      https://www.huffingtonpost.com/entry/advancing...
# 6      https://www.huffingtonpost.com/entry/how-meat-...
# 7      https://www.huffingtonpost.com/entry/boxed-col...
# 8      https://politics.theonion.com/top-snake-handle...
# 9      https://www.huffingtonpost.com/entry/fridays-m...
# 10     https://www.huffingtonpost.com/entry/airline-p...
# 11     https://www.huffingtonpost.com/entry/facebook-...
# 12     https://www.huffingtonpost.comhttp://www.thegu...
# 13     https://www.huffingtonpost.com/entry/jeffrey-l...
# 14     https://www.huffingtonpost.com/entry/barcelona...
# 15     https://entertainment.theonion.com/nuclear-bom...
# 16     https://www.theonion.com/cosby-lawyer-asks-why...
# 17     https://www.theonion.com/stock-analysts-confus...
# 18     https://www.huffingtonpost.com/entry/bloomberg...
# 19     https://www.huffingtonpost.com/entry/craig-hic...
# 20     https://local.theonion.com/courtroom-sketch-ar...
# 21     https://politics.theonion.com/trump-assures-na...
# 22     https://www.huffingtonpost.com/entry/qatar-dut...
# 23     https://www.huffingtonpost.comhttp://pubx.co/d...
# 24     https://www.huffingtonpost.com/entry/ted-cruz-...
# 25     https://www.huffingtonpost.com/entry/why-write...
# 26     https://www.huffingtonpost.com/entry/obama-vet...
# 27     https://local.theonion.com/ex-con-back-behind-...
# 28     https://www.theonion.com/after-careful-conside...
# 29     https://www.huffingtonpost.com/entry/remembran...
# ...                                                  ...
# 26679  https://www.huffingtonpost.com/entry/un-syria-...
# 26680  https://www.theonion.com/kim-jong-un-s-absence...
# 26681  https://www.huffingtonpost.comhttp://pubx.co/M...
# 26682  https://www.huffingtonpost.com/entry/american-...
# 26683  https://www.theonion.com/complete-idiot-forgot...
# 26684  https://politics.theonion.com/retreating-clint...
# 26685  https://local.theonion.com/dont-nobody-wanna-h...
# 26686  https://www.theonion.com/48-syrian-civilians-m...
# 26687  https://www.huffingtonpost.com/entry/readin-re...
# 26688  https://local.theonion.com/report-uttering-phr...
# 26689  https://www.huffingtonpost.com/entry/ted-cruz-...
# 26690  https://www.huffingtonpost.com/entry/myanmar-e...
# 26691  https://local.theonion.com/ice-cube-thrown-int...
# 26692  https://www.huffingtonpost.com/entry/video-int...
# 26693  https://www.theonion.com/new-bailiff-tired-of-...
# 26694  https://www.theonion.com/breaking-the-onion-in...
# 26695  https://www.theonion.com/seaworld-crowd-applau...
# 26696  https://www.huffingtonpost.com/entry/zimbabwe-...
# 26697  https://www.huffingtonpost.com/entry/emma-gonz...
# 26698  https://www.huffingtonpost.com/entry/hackers-b...
# 26699  https://www.huffingtonpost.com/entry/leather-l...
# 26700  https://www.huffingtonpost.com/entry/whats-in-...
# 26701  https://www.huffingtonpost.com/entry/paul-ryan...
# 26702  https://politics.theonion.com/pentagon-to-with...
# 26703  https://www.theonion.com/pope-francis-wearing-...
# 26704  https://www.huffingtonpost.com/entry/american-...
# 26705  https://www.huffingtonpost.com/entry/americas-...
# 26706  https://www.huffingtonpost.com/entry/reparatio...
# 26707  https://www.huffingtonpost.com/entry/israeli-b...
# 26708  https://www.huffingtonpost.com/entry/gourmet-g...
#
#                                                 headline  is_sarcastic
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# 2      mom starting to fear son's web series closest ...             1
# 3      boehner just wants wife to listen, not come up...             1
# 4      j.k. rowling wishes snape happy birthday in th...             0
# 5                            advancing the world's women             0
# 6         the fascinating case for eating lab-grown meat             0
# 7      this ceo will send your kids to school, if you...             0
# 8      top snake handler leaves sinking huckabee camp...             1
# 9      friday's morning email: inside trump's presser...             0
# 10     airline passengers tackle man who rushes cockp...             0
# 11     facebook reportedly working on healthcare feat...             0
# 12     north korea praises trump and urges us voters ...             0
# 13     actually, cnn's jeffrey lord has been 'indefen...             0
# 14     barcelona holds huge protest in support of ref...             0
# 15     nuclear bomb detonates during rehearsal for 's...             1
# 16     cosby lawyer asks why accusers didn't come for...             1
# 17     stock analysts confused, frightened by boar ma...             1
# 18     bloomberg's program to build better cities jus...             0
# 19                                  craig hicks indicted             0
# 20     courtroom sketch artist has clear manga influe...             1
# 21     trump assures nation that decision for syrian ...             1
# 22     qatar deporting dutch woman who reported she w...             0
# 23            this is why you shouldn't go to the circus             0
# 24     ted cruz hits the panic button: 'we could lose...             0
# 25                 why writers must plan to be surprised             0
# 26     obama visits arlington national cemetery to ho...             0
# 27                                ex-con back behind bar             1
# 28     after careful consideration, bush recommends o...             1
# 29              remembrance is the beginning of the task             0
# ...                                                  ...           ...
# 26679  un/opcw report blames syria government, islami...             0
# 26680  kim jong-un's absence leaves north korean gove...             1
# 26681  dog born with odds stacked against her found j...             0
# 26682  american dream week a smashing, mostly uninves...             0
# 26683  complete idiot forgot to shave area between mo...             1
# 26684  retreating clinton campaign torches iowa town ...             1
# 26685     don't nobody wanna hear area man run his mouth             1
# 26686  48 syrian civilians massacred during claire da...             1
# 26687  readin' researchin' writin' and the tools to m...             0
# 26688  report: uttering phrase 'easy does it' prevent...             1
# 26689  ted cruz blasts new york times for keeping boo...             0
# 26690  voting underway in myanmar's first free electi...             0
# 26691  ice cube thrown into sink flies up side like s...             1
# 26692             fisherman's worst nightmare comes true             0
# 26693  new bailiff tired of hearing how old bailiff d...             1
# 26694  breaking: 'the onion' in kill range of boston ...             1
# 26695  seaworld crowd applauds for dolphin playfully ...             1
# 26696  zimbabwe's youth defy blackout to organize pro...             0
# 26697  emma gonzalez: 'one of the biggest threats' to...             0
# 26698  hackers breached u.s. election agency after vo...             0
# 26699  what you should buy your 'basic' friend, accor...             0
# 26700  what's in your mailbox? tips on what to do whe...             0
# 26701           paul ryan is more of a con man than ever             0
# 26702  pentagon to withhold budget figures out of res...             1
# 26703  pope francis wearing sweater vestments he got ...             1
# 26704               american politics in moral free-fall             0
# 26705                            america's best 20 hikes             0
# 26706                              reparations and obama             0
# 26707  israeli ban targeting boycott supporters raise...             0
# 26708                  gourmet gifts for the foodie 2014             0
#
# [26709 rows x 3 columns]

# %%
data=Select_Features(data)

# %%
data
# Out:
#                                                 headline  is_sarcastic
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# 2      mom starting to fear son's web series closest ...             1
# 3      boehner just wants wife to listen, not come up...             1
# 4      j.k. rowling wishes snape happy birthday in th...             0
# 5                            advancing the world's women             0
# 6         the fascinating case for eating lab-grown meat             0
# 7      this ceo will send your kids to school, if you...             0
# 8      top snake handler leaves sinking huckabee camp...             1
# 9      friday's morning email: inside trump's presser...             0
# 10     airline passengers tackle man who rushes cockp...             0
# 11     facebook reportedly working on healthcare feat...             0
# 12     north korea praises trump and urges us voters ...             0
# 13     actually, cnn's jeffrey lord has been 'indefen...             0
# 14     barcelona holds huge protest in support of ref...             0
# 15     nuclear bomb detonates during rehearsal for 's...             1
# 16     cosby lawyer asks why accusers didn't come for...             1
# 17     stock analysts confused, frightened by boar ma...             1
# 18     bloomberg's program to build better cities jus...             0
# 19                                  craig hicks indicted             0
# 20     courtroom sketch artist has clear manga influe...             1
# 21     trump assures nation that decision for syrian ...             1
# 22     qatar deporting dutch woman who reported she w...             0
# 23            this is why you shouldn't go to the circus             0
# 24     ted cruz hits the panic button: 'we could lose...             0
# 25                 why writers must plan to be surprised             0
# 26     obama visits arlington national cemetery to ho...             0
# 27                                ex-con back behind bar             1
# 28     after careful consideration, bush recommends o...             1
# 29              remembrance is the beginning of the task             0
# ...                                                  ...           ...
# 26679  un/opcw report blames syria government, islami...             0
# 26680  kim jong-un's absence leaves north korean gove...             1
# 26681  dog born with odds stacked against her found j...             0
# 26682  american dream week a smashing, mostly uninves...             0
# 26683  complete idiot forgot to shave area between mo...             1
# 26684  retreating clinton campaign torches iowa town ...             1
# 26685     don't nobody wanna hear area man run his mouth             1
# 26686  48 syrian civilians massacred during claire da...             1
# 26687  readin' researchin' writin' and the tools to m...             0
# 26688  report: uttering phrase 'easy does it' prevent...             1
# 26689  ted cruz blasts new york times for keeping boo...             0
# 26690  voting underway in myanmar's first free electi...             0
# 26691  ice cube thrown into sink flies up side like s...             1
# 26692             fisherman's worst nightmare comes true             0
# 26693  new bailiff tired of hearing how old bailiff d...             1
# 26694  breaking: 'the onion' in kill range of boston ...             1
# 26695  seaworld crowd applauds for dolphin playfully ...             1
# 26696  zimbabwe's youth defy blackout to organize pro...             0
# 26697  emma gonzalez: 'one of the biggest threats' to...             0
# 26698  hackers breached u.s. election agency after vo...             0
# 26699  what you should buy your 'basic' friend, accor...             0
# 26700  what's in your mailbox? tips on what to do whe...             0
# 26701           paul ryan is more of a con man than ever             0
# 26702  pentagon to withhold budget figures out of res...             1
# 26703  pope francis wearing sweater vestments he got ...             1
# 26704               american politics in moral free-fall             0
# 26705                            america's best 20 hikes             0
# 26706                              reparations and obama             0
# 26707  israeli ban targeting boycott supporters raise...             0
# 26708                  gourmet gifts for the foodie 2014             0
#
# [26709 rows x 2 columns]

# %%
data['is_sarcastic'].value_counts()
# Out:
# 0    14985
# 1    11724
# Name: is_sarcastic, dtype: int64

# %%
data=Pre_Processing(data)

# %%
data
# Out:
#                                                 headline  is_sarcastic
# 0      former versace store clerk sue secret black co...             0
# 1      roseanne revival catch thorny political mood b...             0
# 2      mom starting fear son web series closest thing...             1
# 3      boehner want wife listen come alternative debt...             1
# 4      j k rowling wish snape happy birthday magical ...             0
# 5                                 advancing world woman              0
# 6                fascinating case eating lab grown meat              0
# 7                      ceo send kid school work company              0
# 8      top snake handler leaf sinking huckabee campaign              1
# 9         friday morning email inside trump presser age              0
# 10     airline passenger tackle man rush cockpit bomb...             0
# 11     facebook reportedly working healthcare feature...             0
# 12     north korea praise trump urge u voter reject d...             0
# 13              actually cnns jeffrey lord indefensible              0
# 14          barcelona hold huge protest support refugee              0
# 15     nuclear bomb detonates rehearsal spider man mu...             1
# 16     cosby lawyer asks accuser didnt come forward s...             1
# 17        stock analyst confused frightened boar market              1
# 18      bloombergs program build better city got bigger              0
# 19                                  craig hick indicted              0
# 20        courtroom sketch artist clear manga influence              1
# 21     trump assures nation decision syrian airstrike...             1
# 22     qatar deporting dutch woman reported drugged r...             0
# 23                                   shouldnt go circus              0
# 24     ted cruz hit panic button could lose house con...             0
# 25                           writer must plan surprised              0
# 26     obama visit arlington national cemetery honor ...             0
# 27                               ex con back behind bar              1
# 28     careful consideration bush recommends oil dril...             1
# 29                           remembrance beginning task              0
# ...                                                  ...           ...
# 26679  un opcw report blame syria government islamic ...             0
# 26680  kim jong un absence leaf north korean governme...             1
# 26681         dog born odds stacked found parent needed              0
# 26682  american dream week smashing mostly uninvestig...             0
# 26683       complete idiot forgot shave area mouth nose              1
# 26684  retreating clinton campaign torch iowa town sl...             1
# 26685         dont nobody wanna hear area man run mouth              1
# 26686  48 syrian civilian massacred claire dane emmy ...             1
# 26687         readin researchin writin tool make happen              0
# 26688  report uttering phrase easy prevents 78 drywal...             1
# 26689  ted cruz blast new york time keeping book best...             0
# 26690  voting underway myanmar first free election 25...             0
# 26691  ice cube thrown sink fly side like skateboarde...             1
# 26692               fisherman worst nightmare come true              0
# 26693       new bailiff tired hearing old bailiff thing              1
# 26694   breaking onion kill range boston bomber suspect              1
# 26695  seaworld crowd applauds dolphin playfully spra...             1
# 26696  zimbabwe youth defy blackout organize protest ...             0
# 26697  emma gonzalez one biggest threat teen today shot              0
# 26698  hacker breached u election agency vote accordi...             0
# 26699              buy basic friend according pinterest              0
# 26700         whats mailbox tip uncle sam come knocking              0
# 26701                            paul ryan con man ever              0
# 26702  pentagon withhold budget figure respect americ...             1
# 26703  pope francis wearing sweater vestment got chri...             1
# 26704                 american politics moral free fall              0
# 26705                              america best 20 hike              0
# 26706                                  reparation obama              0
# 26707  israeli ban targeting boycott supporter raise ...             0
# 26708                          gourmet gift foodie 2014              0
#
# [26709 rows x 2 columns]

# %%
#Remove Low Freq Words
words_tf=Build_TF_Vector(data)

# %%
words_tf=Remove_Low_Freq(words_tf)

# %%
words_tf
# Out:
# {'former': 106,
#  'store': 64,
#  'clerk': 13,
#  'sue': 32,
#  'secret': 118,
#  'black': 276,
#  'code': 21,
#  'minority': 19,
#  'shopper': 9,
#  'revival': 11,
#  'catch': 33,
#  'political': 83,
#  'mood': 13,
#  'better': 124,
#  'worse': 40,
#  'mom': 267,
#  'starting': 45,
#  'fear': 66,
#  'son': 147,
#  'web': 19,
#  'series': 62,
#  'closest': 7,
#  'thing': 361,
#  'grandchild': 5,
#  'boehner': 27,
#  'want': 305,
#  'wife': 100,
#  'listen': 24,
#  'come': 180,
#  'alternative': 15,
#  'debt': 31,
#  'reduction': 5,
#  'idea': 116,
#  'j': 49,
#  'k': 53,
#  'rowling': 7,
#  'wish': 76,
#  'happy': 64,
#  'birthday': 67,
#  'magical': 32,
#  'way': 392,
#  'world': 384,
#  'woman': 883,
#  'case': 116,
#  'eating': 76,
#  'lab': 8,
#  'grown': 18,
#  'meat': 30,
#  'ceo': 84,
#  'send': 35,
#  'kid': 256,
#  'school': 302,
#  'work': 218,
#  'company': 131,
#  'top': 141,
#  'snake': 13,
#  'handler': 7,
#  'leaf': 70,
#  'sinking': 6,
#  'huckabee': 20,
#  'campaign': 207,
#  'friday': 52,
#  'morning': 101,
#  'email': 117,
#  'inside': 83,
#  'trump': 1686,
#  'age': 82,
#  'airline': 46,
#  'passenger': 41,
#  'tackle': 11,
#  'man': 1396,
#  'rush': 27,
#  'bomb': 27,
#  'threat': 62,
#  'facebook': 112,
#  'reportedly': 48,
#  'working': 78,
#  'healthcare': 26,
#  'feature': 41,
#  'apps': 10,
#  'north': 132,
#  'korea': 78,
#  'praise': 26,
#  'urge': 58,
#  'u': 617,
#  'voter': 135,
#  'reject': 17,
#  'hillary': 213,
#  'actually': 134,
#  'cnns': 9,
#  'lord': 17,
#  'hold': 57,
#  'huge': 58,
#  'protest': 87,
#  'support': 112,
#  'refugee': 77,
#  'nuclear': 67,
#  'spider': 15,
#  'musical': 25,
#  'cosby': 15,
#  'lawyer': 54,
#  'asks': 88,
#  'accuser': 14,
#  'didnt': 96,
#  'forward': 39,
#  'legal': 36,
#  'team': 98,
#  'year': 799,
#  'ago': 31,
#  'stock': 27,
#  'analyst': 10,
#  'confused': 12,
#  'boar': 5,
#  'market': 39,
#  'program': 60,
#  'build': 32,
#  'city': 161,
#  'got': 145,
#  'bigger': 14,
#  'craig': 10,
#  'hick': 9,
#  'indicted': 12,
#  'sketch': 11,
#  'artist': 73,
#  'clear': 32,
#  'influence': 17,
#  'assures': 29,
#  'nation': 372,
#  'decision': 58,
#  'syrian': 57,
#  'airstrikes': 6,
#  'came': 33,
#  'carefully': 11,
#  'considering': 16,
#  'passing': 22,
#  'qatar': 9,
#  'dutch': 5,
#  'reported': 13,
#  'raped': 7,
#  'shouldnt': 34,
#  'go': 254,
#  'circus': 5,
#  'ted': 66,
#  'cruz': 72,
#  'hit': 109,
#  'panic': 19,
#  'button': 13,
#  'could': 281,
#  'lose': 46,
#  'house': 366,
#  'congress': 134,
#  'writer': 41,
#  'must': 103,
#  'plan': 228,
#  'surprised': 32,
#  'obama': 362,
#  'visit': 80,
#  'national': 131,
#  'cemetery': 5,
#  'honor': 59,
#  'veteran': 44,
#  'ex': 75,
#  'con': 14,
#  'back': 342,
#  'behind': 94,
#  'bar': 72,
#  'careful': 5,
#  'consideration': 5,
#  'bush': 161,
#  'recommends': 28,
#  'oil': 50,
#  'drilling': 9,
#  'beginning': 23,
#  'task': 6,
#  'ally': 29,
#  'islamist': 5,
#  'killing': 59,
#  'nonsense': 11,
#  'like': 433,
#  'kiss': 15,
#  'adam': 23,
#  'uber': 30,
#  'vow': 57,
#  'nyc': 44,
#  'driver': 54,
#  'ten': 15,
#  'million': 197,
#  'tax': 111,
#  'apple': 57,
#  'may': 203,
#  'electric': 17,
#  'motorcycle': 9,
#  'death': 240,
#  'drug': 95,
#  'resistant': 6,
#  'bacteria': 11,
#  'often': 8,
#  'childrens': 24,
#  'dog': 185,
#  'see': 196,
#  'muslim': 95,
#  'airport': 41,
#  'giant': 42,
#  'heading': 7,
#  'toward': 38,
#  'earth': 75,
#  'straight': 61,
#  'box': 65,
#  'office': 157,
#  'massive': 51,
#  '1': 142,
#  'opening': 44,
#  'money': 129,
#  'baseball': 25,
#  'lost': 73,
#  'next': 159,
#  'generation': 38,
#  'fan': 160,
#  'robin': 13,
#  'williams': 45,
#  'holiday': 91,
#  'eighth': 7,
#  'devin': 5,
#  'nunes': 6,
#  'never': 170,
#  'reveal': 41,
#  'source': 36,
#  'surveillance': 11,
#  'claim': 114,
#  'scott': 58,
#  'used': 91,
#  'stop': 187,
#  'breathing': 11,
#  'nearly': 36,
#  '40': 51,
#  'time': 520,
#  'hour': 133,
#  'device': 11,
#  'changed': 27,
#  'life': 453,
#  'rescuer': 7,
#  'help': 169,
#  'garbage': 12,
#  'ocean': 28,
#  'drop': 54,
#  'soccer': 27,
#  'player': 59,
#  'he': 157,
#  'give': 196,
#  'gift': 82,
#  'play': 78,
#  'season': 139,
#  'christian': 46,
#  'bale': 5,
#  'sikh': 9,
#  'temple': 5,
#  'victim': 82,
#  'spicer': 18,
#  'denies': 19,
#  'ending': 19,
#  'maternity': 5,
#  'care': 147,
#  'would': 238,
#  'mean': 71,
#  'pay': 102,
#  'health': 210,
#  'right': 293,
#  'live': 141,
#  'complete': 30,
#  'stunned': 10,
#  'horror': 28,
#  'added': 12,
#  'constitution': 17,
#  'nasa': 36,
#  'almost': 51,
#  'positive': 22,
#  'mar': 31,
#  'rocky': 9,
#  'monster': 20,
#  'night': 149,
#  'light': 68,
#  'diy': 6,
#  'sport': 62,
#  'closet': 16,
#  'dead': 184,
#  '3': 242,
#  'injured': 26,
#  'shooting': 138,
#  'concert': 29,
#  'longtime': 14,
#  'teacher': 124,
#  'retires': 8,
#  'without': 116,
#  'changing': 34,
#  'single': 112,
#  'student': 218,
#  'donald': 472,
#  'win': 161,
#  'poll': 115,
#  'say': 664,
#  'wouldnt': 23,
#  'ready': 80,
#  'cash': 28,
#  'self': 188,
#  'finance': 12,
#  'entire': 106,
#  'analysis': 7,
#  'new': 1523,
#  'star': 237,
#  'war': 216,
#  'film': 131,
#  'die': 58,
#  'hard': 68,
#  'bat': 14,
#  'tunnel': 11,
#  'summer': 82,
#  'mobile': 7,
#  'news': 174,
#  'crew': 26,
#  'report': 594,
#  'van': 20,
#  'breaking': 74,
#  'un': 57,
#  'chief': 75,
#  'call': 281,
#  'humanitarian': 6,
#  'situation': 19,
#  'syria': 58,
#  'outrage': 8,
#  'track': 48,
#  'santa': 27,
#  'claus': 5,
#  'flight': 48,
#  'around': 143,
#  'christmas': 98,
#  'eve': 15,
#  'colorado': 22,
#  'trouble': 19,
#  'tv': 119,
#  'africa': 22,
#  'unveils': 80,
#  'throat': 11,
#  'water': 81,
#  'filter': 10,
#  'john': 173,
#  'slowly': 28,
#  'list': 79,
#  'greatest': 30,
#  'living': 79,
#  'american': 522,
#  'author': 26,
#  'ghost': 16,
#  'cant': 225,
#  'make': 508,
#  'simple': 41,
#  'cup': 37,
#  'coffee': 46,
#  'everyone': 115,
#  'freaking': 12,
#  'truly': 20,
#  'red': 80,
#  'curry': 13,
#  'leftover': 10,
#  'one': 561,
#  'planet': 48,
#  'powerful': 53,
#  'force': 80,
#  'change': 210,
#  'girl': 204,
#  'green': 43,
#  'take': 342,
#  'game': 184,
#  'level': 47,
#  'area': 498,
#  'said': 39,
#  'sorry': 25,
#  'ryan': 84,
#  'lochte': 5,
#  'apologizes': 39,
#  'behavior': 24,
#  'rio': 10,
#  'dakota': 20,
#  'heard': 30,
#  '4': 167,
#  'lesson': 69,
#  'prison': 65,
#  'taught': 18,
#  'power': 109,
#  'control': 96,
#  'sick': 49,
#  'fuck': 49,
#  'line': 119,
#  'body': 130,
#  'america': 237,
#  'first': 435,
#  'really': 231,
#  'vicious': 5,
#  'process': 26,
#  'contains': 11,
#  'solution': 24,
#  'congressman': 68,
#  'think': 202,
#  'fix': 29,
#  'economy': 42,
#  'drinking': 27,
#  'beer': 36,
#  'breast': 23,
#  'implant': 8,
#  'found': 106,
#  'cause': 44,
#  'problem': 106,
#  'mouse': 14,
#  'order': 99,
#  'strike': 52,
#  'chemical': 19,
#  'attack': 181,
#  'funeral': 23,
#  'dream': 106,
#  'round': 20,
#  '90': 38,
#  'pledge': 33,
#  'culture': 43,
#  'foster': 10,
#  'abuse': 49,
#  'nypd': 13,
#  'weighs': 11,
#  'allowing': 13,
#  'following': 57,
#  'eric': 37,
#  'garner': 11,
#  'bono': 5,
#  'foundation': 22,
#  'prevents': 5,
#  'risk': 60,
#  'youth': 43,
#  'tree': 43,
#  'pope': 116,
#  'francis': 65,
#  'reminds': 37,
#  'caring': 9,
#  'everyones': 7,
#  'responsibility': 16,
#  '6': 155,
#  'old': 402,
#  'cry': 34,
#  'told': 61,
#  'production': 19,
#  'kitten': 14,
#  'boyfriend': 46,
#  'thought': 91,
#  'hed': 15,
#  'check': 63,
#  'throw': 68,
#  'day': 554,
#  'doctor': 81,
#  'restore': 12,
#  'ken': 13,
#  'burn': 25,
#  'full': 93,
#  'color': 46,
#  'vision': 24,
#  'removing': 7,
#  'tumor': 6,
#  'filmmaker': 6,
#  'visual': 6,
#  '12': 91,
#  'slave': 12,
#  'tie': 31,
#  '2014': 46,
#  'award': 87,
#  'coming': 101,
#  '150': 11,
#  'lgbtq': 41,
#  'people': 401,
#  'last': 231,
#  'oliver': 15,
#  'lay': 19,
#  'disturbing': 13,
#  'impact': 18,
#  'gop': 263,
#  'crackdown': 12,
#  'continues': 29,
#  'sure': 84,
#  'skill': 24,
#  'please': 28,
#  'grandson': 12,
#  'queen': 49,
#  'elizabeth': 39,
#  'meghan': 13,
#  'markle': 8,
#  'visiting': 25,
#  'hometown': 14,
#  'find': 320,
#  'childhood': 17,
#  'insecurity': 5,
#  'still': 332,
#  'look': 244,
#  'attacked': 6,
#  'bug': 7,
#  'clinton': 341,
#  'becomes': 32,
#  'president': 249,
#  '18': 41,
#  'foot': 49,
#  'pole': 6,
#  'vault': 5,
#  'hunter': 12,
#  'thompson': 11,
#  'shoot': 39,
#  'mouth': 32,
#  'grand': 16,
#  'climate': 130,
#  'conspiracy': 19,
#  'theory': 34,
#  'barbra': 5,
#  'streisand': 5,
#  '5': 302,
#  'question': 111,
#  'younger': 19,
#  'asking': 42,
#  'shooter': 32,
#  'loose': 13,
#  'gunman': 19,
#  'everything': 80,
#  'flood': 21,
#  'demi': 6,
#  'lovato': 6,
#  'emotional': 41,
#  'music': 83,
#  'miley': 13,
#  'cyrus': 15,
#  'hemsworth': 8,
#  'notice': 16,
#  'jealous': 7,
#  'gps': 22,
#  'clearly': 43,
#  'park': 55,
#  'morale': 5,
#  'queer': 55,
#  'italy': 16,
#  'tour': 47,
#  '2015': 61,
#  'cindy': 5,
#  'daughter': 99,
#  'land': 36,
#  'major': 45,
#  'fashion': 54,
#  'l': 19,
#  'grant': 19,
#  'net': 17,
#  'james': 98,
#  'corden': 20,
#  'roast': 11,
#  'david': 56,
#  'outfit': 15,
#  'café': 9,
#  'add': 67,
#  'heartbreaking': 16,
#  'little': 183,
#  'lunch': 34,
#  'menu': 12,
#  'mcdonalds': 21,
#  '100': 61,
#  'percent': 69,
#  'kris': 10,
#  'jenner': 50,
#  'turned': 21,
#  'drunken': 8,
#  'valentine': 35,
#  'karaoke': 8,
#  'whale': 19,
#  'regret': 28,
#  '000': 189,
#  'plastic': 23,
#  'chip': 12,
#  'fell': 9,
#  'container': 12,
#  'ship': 20,
#  'texas': 76,
#  'ebola': 41,
#  'patient': 37,
#  'fighting': 49,
#  'late': 59,
#  'audition': 6,
#  'perfect': 83,
#  'actor': 55,
#  'role': 48,
#  'head': 107,
#  'room': 92,
#  'producer': 22,
#  'giving': 63,
#  'hope': 95,
#  'robert': 52,
#  'de': 25,
#  'turn': 102,
#  '58': 7,
#  'movie': 152,
#  'pruitt': 16,
#  'sort': 24,
#  'answer': 36,
#  'whether': 45,
#  'belief': 27,
#  'accused': 55,
#  'father': 116,
#  'urinal': 5,
#  'thief': 9,
#  'cop': 115,
#  'slow': 18,
#  'youll': 33,
#  'fine': 28,
#  'drunk': 55,
#  'away': 119,
#  'stolen': 16,
#  'police': 234,
#  'car': 129,
#  'libertarian': 6,
#  'fuel': 16,
#  '7': 159,
#  'super': 86,
#  'pac': 19,
#  'philadelphia': 16,
#  'democratic': 61,
#  'primary': 43,
#  'air': 75,
#  'longer': 47,
#  'require': 8,
#  'god': 136,
#  'oath': 11,
#  'paul': 121,
#  'dy': 77,
#  'consuming': 7,
#  'egg': 29,
#  'chew': 6,
#  'worried': 50,
#  'dealer': 6,
#  'who': 34,
#  'picking': 5,
#  'phone': 79,
#  'dad': 185,
#  'hotel': 49,
#  '10': 224,
#  'mile': 31,
#  'youre': 78,
#  'explosion': 14,
#  'building': 47,
#  'outside': 61,
#  'paris': 47,
#  'least': 55,
#  '2': 216,
#  'military': 67,
#  'finally': 131,
#  'revealed': 15,
#  'union': 66,
#  'sander': 110,
#  'staffer': 29,
#  'member': 74,
#  'worker': 91,
#  'seattle': 16,
#  'mayor': 43,
#  'sex': 156,
#  'lawsuit': 39,
#  'southern': 8,
#  'comfort': 19,
#  'featured': 6,
#  'fox': 62,
#  'edited': 6,
#  'plus': 17,
#  'size': 27,
#  'model': 39,
#  'runway': 8,
#  'baltimore': 14,
#  'rapper': 14,
#  'inspire': 10,
#  'quality': 19,
#  'inner': 18,
#  'spirit': 25,
#  'jewish': 20,
#  'boy': 133,
#  'parenting': 28,
#  'advice': 47,
#  'id': 18,
#  'dare': 6,
#  'family': 331,
#  'chooses': 8,
#  'different': 62,
#  'grandfather': 13,
#  'celebrity': 60,
#  'celebrate': 42,
#  'fourth': 30,
#  'july': 14,
#  'fun': 61,
#  'sun': 21,
#  'international': 28,
#  'western': 12,
#  'save': 102,
#  'michelle': 44,
#  'beauty': 45,
#  'caitlyn': 15,
#  'responds': 39,
#  'golden': 35,
#  'globe': 25,
#  'joke': 43,
#  'joy': 23,
#  'michael': 78,
#  'flynn': 11,
#  'guilty': 31,
#  'plea': 19,
#  'pure': 12,
#  'tell': 187,
#  'weight': 51,
#  'loss': 40,
#  'journey': 24,
#  'disappointed': 26,
#  'learn': 41,
#  'ron': 12,
#  'marriage': 98,
#  'break': 108,
#  'difference': 23,
#  'yo': 11,
#  'raise': 58,
#  'california': 90,
#  'engineering': 5,
#  'warren': 31,
#  'racist': 44,
#  'bully': 13,
#  'six': 37,
#  'hurt': 30,
#  'commuter': 5,
#  'bus': 52,
#  'crash': 64,
#  'kim': 72,
#  'gordon': 8,
#  'clarifies': 8,
#  'comment': 46,
#  'del': 7,
#  'feminism': 13,
#  'bashar': 6,
#  'al': 61,
#  'assad': 13,
#  'try': 77,
#  'tiny': 25,
#  'bit': 20,
#  'gas': 32,
#  'cancer': 75,
#  'im': 93,
#  'arrested': 41,
#  'charged': 27,
#  'driving': 51,
#  'need': 271,
#  'know': 282,
#  'controversy': 25,
#  'erupts': 9,
#  'uk': 17,
#  'retailer': 5,
#  'remove': 34,
#  'gender': 31,
#  'label': 12,
#  'clothes': 22,
#  'bitch': 12,
#  'sixth': 15,
#  'grade': 28,
#  'class': 85,
#  'insurance': 31,
#  'salesman': 11,
#  'celebrates': 58,
#  'friend': 239,
#  'always': 78,
#  'best': 244,
#  'neil': 19,
#  'watch': 243,
#  'another': 146,
#  'sci': 8,
#  'fi': 11,
#  'physicist': 6,
#  'biologist': 7,
#  'announce': 36,
#  'theyre': 54,
#  'done': 39,
#  'megyn': 8,
#  'kelly': 41,
#  'story': 155,
#  'project': 34,
#  'going': 213,
#  'viral': 30,
#  'creating': 21,
#  'none': 7,
#  'seems': 21,
#  'exist': 12,
#  'tap': 16,
#  'love': 244,
#  'rapping': 5,
#  'newspaper': 30,
#  'worry': 21,
#  'spending': 33,
#  'much': 137,
#  'healthy': 38,
#  'matter': 63,
#  'central': 16,
#  'meaning': 15,
#  'amendment': 19,
#  'vatican': 30,
#  'putting': 35,
#  'public': 101,
#  'react': 9,
#  'wire': 11,
#  'cast': 36,
#  'reunited': 8,
#  'community': 81,
#  'obamas': 68,
#  'supreme': 116,
#  'court': 188,
#  'nominee': 37,
#  'sending': 16,
#  'free': 120,
#  'c': 55,
#  'security': 93,
#  'guard': 28,
#  'custody': 12,
#  'ruled': 6,
#  'homicide': 8,
#  'leave': 62,
#  'clean': 44,
#  'minute': 141,
#  'push': 56,
#  'appeal': 23,
#  'white': 339,
#  'facing': 12,
#  'rising': 21,
#  'sea': 36,
#  'remote': 13,
#  'village': 12,
#  'vote': 124,
#  'move': 97,
#  'child': 312,
#  'memory': 33,
#  'trying': 118,
#  'worst': 50,
#  'place': 99,
#  'sentenced': 19,
#  'encouraging': 10,
#  'assault': 69,
#  'baby': 171,
#  'value': 32,
#  'march': 69,
#  'inspired': 33,
#  'run': 129,
#  'men': 133,
#  'worth': 47,
#  'senator': 93,
#  'arent': 37,
#  'accept': 15,
#  'champion': 13,
#  'price': 42,
#  'failing': 24,
#  'harsh': 6,
#  'past': 74,
#  'bacon': 15,
#  'cheeseburger': 5,
#  'toaster': 6,
#  'completes': 14,
#  'documentary': 45,
#  'fucking': 68,
#  'liar': 15,
#  'watched': 14,
#  'jazz': 11,
#  'magic': 22,
#  'initial': 5,
#  'fail': 25,
#  'rice': 15,
#  'cake': 28,
#  'stunning': 34,
#  'surprise': 60,
#  'carly': 13,
#  'rae': 8,
#  'released': 31,
#  'jeopardy': 7,
#  'clue': 9,
#  'female': 85,
#  'getting': 185,
#  'lot': 77,
#  'avoiding': 5,
#  'touching': 19,
#  'male': 47,
#  'patron': 21,
#  'hand': 97,
#  'kill': 120,
#  'wound': 6,
#  'four': 40,
#  'german': 20,
#  'nightclub': 8,
#  'couple': 162,
#  'point': 85,
#  'comfortable': 15,
#  'using': 57,
#  'toilet': 18,
#  'mountain': 16,
#  'lion': 11,
#  'scientist': 93,
#  'near': 48,
#  'road': 54,
#  'noah': 30,
#  'debut': 39,
#  'scalia': 16,
#  'abortion': 70,
#  'passed': 12,
#  'justice': 86,
#  'big': 205,
#  'sized': 6,
#  'finish': 27,
#  'fry': 13,
#  'taylor': 56,
#  'swift': 45,
#  'voice': 62,
#  'writing': 31,
#  '1989': 6,
#  'restaurant': 82,
#  'challenge': 42,
#  'reward': 8,
#  'meal': 46,
#  'placed': 10,
#  'eat': 47,
#  'avocado': 6,
#  'plate': 14,
#  '70': 21,
#  'holy': 15,
#  'shit': 68,
#  'open': 148,
#  'letter': 84,
#  'progressive': 26,
#  'tpp': 6,
#  'yet': 69,
#  'trade': 38,
#  'agreement': 11,
#  'history': 120,
#  'modern': 25,
#  'offer': 81,
#  'united': 54,
#  'offering': 26,
#  'immigrant': 66,
#  'special': 66,
#  'circle': 15,
#  'gap': 35,
#  'travel': 65,
#  'ban': 104,
#  'thinking': 59,
#  'thomas': 20,
#  'retirement': 35,
#  'video': 227,
#  'anti': 127,
#  'hate': 78,
#  'group': 119,
#  'long': 133,
#  'silent': 12,
#  'post': 103,
#  'window': 38,
#  'struggling': 47,
#  'helped': 28,
#  'friendly': 20,
#  'breakup': 12,
#  'bos': 39,
#  'malcolm': 6,
#  'middle': 106,
#  'reboot': 10,
#  'future': 105,
#  'unemployed': 14,
#  'sibling': 16,
#  'mother': 135,
#  'voted': 13,
#  'favorite': 62,
#  'pin': 8,
#  'number': 78,
#  'thank': 25,
#  'thursday': 18,
#  'part': 120,
#  'toe': 9,
#  'arctic': 13,
#  'canada': 15,
#  'looney': 5,
#  'front': 58,
#  'happen': 29,
#  'mark': 72,
#  'zuckerberg': 14,
#  'contempt': 7,
#  'refusing': 12,
#  'shut': 34,
#  'started': 17,
#  'dorm': 12,
#  'rubio': 46,
#  'supporter': 55,
#  'get': 586,
#  'stranger': 43,
#  'review': 53,
#  'dr': 21,
#  'lloyd': 5,
#  'updated': 11,
#  'accommodate': 5,
#  'ordered': 14,
#  'moon': 26,
#  'feast': 6,
#  'nasty': 10,
#  ...}

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(data, test_size = 0.3,shuffle=True)
train.reset_index(inplace=True, drop=True)
test.reset_index(inplace=True, drop=True)

# %%
print("Train_Dataset: ",len(train))
print("Test_dataset",len(test))
# Out:
# Train_Dataset:  18696
# Test_dataset 8013

# %%
train.head()
# Out:
#                                             headline  is_sarcastic
# 0  ex nfl player lament knowing cte prior footbal...             0
# 1          bos wax nostalgic sexual harassment suit              1
# 2     house republican unveil bill repeal obamacare              0
# 3                      3 reason picked wrong doctor              0
# 4  american expect government official issue marr...             0

# %%
test.head()
# Out:
#                                             headline  is_sarcastic
# 0  doj monitoring investigation fatal police shoo...             0
# 1  investigation expose ebay user selling fake pu...             1
# 2                               glass new accessory              0
# 3  middle aged cat cant begin compete adorable ki...             1
# 4  olympic skier stare icy forbidding slope rest ...             1

# %%
train_dataset=NaiveBayes(train,words_tf.keys())

# %%
predicted=test_dataset(train_dataset,test)

# %%
actual=list(test['is_sarcastic'])
acc=Accuracy(actual,predicted)

# %%
print("Accuracy is : ",acc)
print("Rounded-Accurcy",math.ceil(acc))
# Out:
# Accuracy is :  78.85935355048048
# Rounded-Accurcy 79

# %%
test_output=test.copy()
test_output=test_output.drop(['is_sarcastic'],axis=1)
test_output['is_sarcastic']=predicted

# %%
test_output
# Out:
#                                                headline  is_sarcastic
# 0     doj monitoring investigation fatal police shoo...             0
# 1     investigation expose ebay user selling fake pu...             0
# 2                                  glass new accessory              1
# 3     middle aged cat cant begin compete adorable ki...             1
# 4     olympic skier stare icy forbidding slope rest ...             1
# 5                new u currency expires spent two week              1
# 6               moving new city solve area man problem              1
# 7        4 uncommon serious ear infection complication              0
# 8     stepson absolutely nailing jeopardy category t...             1
# 9     bush proud u economic woe still depress world ...             1
# 10    nation could probably draw john boehner memory...             1
# 11    biggest loser high school adjusting ordinary l...             1
# 12          duggar sister say josh little curious girl              0
# 13                 huffpost rise need know february 26              0
# 14         nancy pelosi paul ryan get mixed mark party              1
# 15    nation surprised took long primary weed candid...             1
# 16    parent abandoned 2 year old son play pokemon g...             0
# 17       phone call dad watered version phone call mom              1
# 18    report average person spends 18 hour standing ...             1
# 19    surprise bidder weinstein company want embattl...             0
# 20    democrat block every trump supreme court justice              0
# 21                          michelangelo david updated              0
# 22    artist merges gender late lover ultimate artis...             0
# 23    study find people date know within 30 second p...             1
# 24                          top talent passing company              1
# 25                    trump fire rosenstein may matter              0
# 26               john oliver heartfelt message orlando              0
# 27                           author use water metaphor              1
# 28                christophe michalak pastry superhero              1
# 29    creator michelle rodriguezs new film defend cl...             0
# ...                                                 ...           ...
# 7983    johnson johnson introduces self lotioning baby              1
# 7984                      nation tall asked stand back              1
# 7985  entire republican national convention stunned ...             1
# 7986    breaking way egypt coming functional democracy              0
# 7987                jay pharoah spoof usher bad kisser              0
# 7988               ugly man huge penis unsure get word              1
# 7989          jurisprudence fetishist get technicality              1
# 7990                        give bedroom polished look              0
# 7991     world weary sigh emanates next bathroom stall              1
# 7992                                people say talking              0
# 7993                                bad bone used film              1
# 7994  pour rihanna celebrates grammy win rumored boy...             1
# 7995                       child assured monster exist              1
# 7996  census bureau release annual report neighborho...             1
# 7997  gop congressman getting rich solve whole envir...             1
# 7998             hugh hefner fan twitter thank article              0
# 7999              thousand protest moscow housing plan              0
# 8000  cnn contributor compare trump campaign gulp ch...             0
# 8001  custody battle spark couple first ever interes...             1
# 8002          4 must digital marketing core competency              0
# 8003       gummi bear emerges digestive tract unharmed              1
# 8004               nation school system held back year              1
# 8005  trump claim star david picture isnt anti semitic              0
# 8006                                      snowman suck              1
# 8007    world miss goal universal education 50 year un              0
# 8008  john kerry issue dire warning israeli settleme...             0
# 8009   frocked podium boy shine pre state union ritual              1
# 8010                         rick steves cleaned gypsy              1
# 8011           bird arthritis epidemic largely ignored              1
# 8012      exxonmobil swears going start tax early year              1
#
# [8013 rows x 2 columns]

# %%
sent_input=input("Enter The Sentence : ")
# Out:
# Enter The Sentence : Liberals will not buy this book, so their opinion is worthless. Besides most of them cant even read clearly enough to get the joke

# %%
sent_input=remove_symbols(sent_input)
sent_input=remove_stop_words(sent_input)

# %%
ans=check_sentence(train_dataset,sent_input)

# %%
print(ans)
# Out:
# Sarcastic
